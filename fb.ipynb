# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.limit(10).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.limit(10).fields(likes.limit(10))&access_token=CAACEdEose0cBAEonNN3jSmMGukIaexqXJS7oJIHVxsCYVZCpO6HYq0KLaIAy8BQX6SXPhUP2H2sXruPQZAAXGNfnAzZBHCHfFJ7PSNyObHTOqmdoWlfWJDZCGGYbVcm4ZADfvW4FZAwmZCGGOgCw6EJwR9LThufOCKgDbyaqugUWoZB5wseZCJsOg3toh0T9wLYzmgOebZBSXG2wZDZD
# {
#  "error": {
#   "message": "Error validating access token: Session has expired at unix time 1386673200. The current unix time is 1386714848.",
#   "code": 190,
#   "type": "OAuthException",
#   "error_subcode": 463
#  }
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "username": "khoa.tran.397",
#  "first_name": "Khoa",
#  "last_name": "Tran",
#  "verified": true,
#  "name": "Khoa Tran",
#  "locale": "en_US",
#  "hometown": {
#   "id": "108458769184495",
#   "name": "Ho Chi Minh City, Vietnam"
#  },
#  "updated_time": "2013-11-19T08:08:16+0000",
#  "birthday": "10/16/1992",
#  "link": "https://www.facebook.com/khoa.tran.397",
#  "location": {
#   "id": "113857331958379",
#   "name": "Berkeley, California"
#  },
#  "favorite_athletes": [
#   {
#    "id": "164003850323607",
#    "name": "Thank You Edge"
#   },
#   {
#    "id": "114681195238350",
#    "name": "Shawn Michaels"
#   },
#   {
#    "id": "180457552010675",
#    "name": "Thank You! Cm Punk"
#   }
#  ],
#  "gender": "male",
#  "timezone": -8,
#  "education": [
#   {
#    "school": {
#     "id": "120489131309742",
#     "name": "THPT Chuy\u00ean Tr\u1ea7n \u0110\u1ea1i Ngh\u0129a"
#    },
#    "type": "High School",
#    "year": {
#     "id": "142963519060927",
#     "name": "2010"
#    }
#   },
#   {
#    "school": {
#     "id": "103145396391942",
#     "name": "Tran Dai Nghia High School"
#    },
#    "classes": [
#     {
#      "from": {
#       "id": "1609728502",
#       "name": "Duyen Truong"
#      },
#      "with": [
#       {
#        "id": "1609728502",
#        "name": "Duyen Truong"
#       }
#      ],
#      "id": "134653589933346",
#      "name": "10A1, 11A1"
#     }
#    ],
#    "type": "High School"
#   },
#   {
#    "school": {
#     "id": "10111634660",
#     "name": "UC Berkeley"
#    },
#    "type": "College"
#   }
#  ],
#  "id": "1780707149"
# }
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/1780707149/friends?access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&limit=5000&offset=5000&__after_id=100006763153362"
#  },
#  "data": [
#   {
#    "name": "Teresa Rose Tenfelder",
#    "id": "524467125"
#   },
#   {
#    "name": "Phuoc 'Kiddo' Nguyen",
#    "id": "524711216"
#   },
#   {
#    "name": "Alice Man",
#    "id": "525281635"
#   },
#   {
#    "name": "\u0422\u0435\u0439\u043c\u0443\u0440 \u041c\u0443\u0437\u0448\u0444\u0435\u043a",
#    "id": "571921877"
#   },
#   {
#    "name": "Hien Le",
#    "id": "574133128"
#   },
#   {
#    "name": "Joey Amerison",
#    "id": "579780120"
#   },
#   {
#    "name": "Ethan Bauer",
#    "id": "588969378"
#   },
#   {
#    "name": "Ami Bigit",
#    "id": "601925220"
#   },
#   {
#    "name": "David Smith",
#    "id": "603558153"
#   },
#   {
#    "name": "M\u0169m M\u0129m",
#    "id": "619347099"
#   },
#   {
#    "name": "David Casas-Mao",
#    "id": "626197917"
#   },
#   {
#    "name": "Reena Shah",
#    "id": "629906652"
#   },
#   {
#    "name": "Claire Thompson",
#    "id": "636903711"
#   },
#   {
#    "name": "Ben Lewis",
#    "id": "637460591"
#   },
#   {
#    "name": "Dang Dinh Hung",
#    "id": "651498500"
#   },
#   {
#    "name": "Michael Suey",
#    "id": "657168509"
#   },
#   {
#    "name": "Roland Shen",
#    "id": "663755597"
#   },
#   {
#    "name": "Darrell Vermilion",
#    "id": "677204394"
#   },
#   {
#    "name": "Vy Do",
#    "id": "711624999"
#   },
#   {
#    "name": "David Barrera",
#    "id": "720055222"
#   },
#   {
#    "name": "Michael Zhang",
#    "id": "723757561"
#   },
#   {
#    "name": "Morgan Fabian",
#    "id": "736758580"
#   },
#   {
#    "name": "Phuc Nguyen",
#    "id": "740148375"
#   },
#   {
#    "name": "Radhesh Devendran",
#    "id": "750911386"
#   },
#   {
#    "name": "Alisha King",
#    "id": "757737974"
#   },
#   {
#    "name": "Nguyen Dat",
#    "id": "794793150"
#   },
#   {
#    "name": "Hao Le",
#    "id": "805784485"
#   },
#   {
#    "name": "Tue Cao Mai",
#    "id": "848419448"
#   },
#   {
#    "name": "Vi\u1ec7t Huy",
#    "id": "1028794030"
#   },
#   {
#    "name": "Christina Ho",
#    "id": "1030830109"
#   },
#   {
#    "name": "Takeo Hiraki",
#    "id": "1036114731"
#   },
#   {
#    "name": "Luffy H. T\u1eeb",
#    "id": "1046093913"
#   },
#   {
#    "name": "Ph\u1ea1m Minh Tr\u00ed",
#    "id": "1117667156"
#   },
#   {
#    "name": "Trung Bim",
#    "id": "1118536327"
#   },
#   {
#    "name": "Elese Lorentzen-Gadd",
#    "id": "1119286520"
#   },
#   {
#    "name": "Linh Nguyen",
#    "id": "1128225389"
#   },
#   {
#    "name": "Mina Pham",
#    "id": "1151500765"
#   },
#   {
#    "name": "\u0110\u00e0o Ng\u1ecdc \u0110\u0103ng Khoa",
#    "id": "1155400636"
#   },
#   {
#    "name": "Ietee Pandey",
#    "id": "1156267112"
#   },
#   {
#    "name": "Su Htet Htet Win",
#    "id": "1165350780"
#   },
#   {
#    "name": "Thien Anh Vo",
#    "id": "1182189233"
#   },
#   {
#    "name": "Ferheen Abbasi",
#    "id": "1191998340"
#   },
#   {
#    "name": "Andrew Koth",
#    "id": "1240321988"
#   },
#   {
#    "name": "Minh Tri Le",
#    "id": "1244167516"
#   },
#   {
#    "name": "Fatty An Tran",
#    "id": "1244758389"
#   },
#   {
#    "name": "Vinay Gupta",
#    "id": "1270448975"
#   },
#   {
#    "name": "Kamran Siddiqui",
#    "id": "1283414140"
#   },
#   {
#    "name": "Annie Pham",
#    "id": "1284741892"
#   },
#   {
#    "name": "Jennifer Fei",
#    "id": "1292029987"
#   },
#   {
#    "name": "Dan Le",
#    "id": "1311419171"
#   },
#   {
#    "name": "Cheryl Kwan",
#    "id": "1326058456"
#   },
#   {
#    "name": "H\u1ea1nh \u0110inh",
#    "id": "1339614744"
#   },
#   {
#    "name": "Minh Slim",
#    "id": "1367952086"
#   },
#   {
#    "name": "Alex Matevish",
#    "id": "1367963782"
#   },
#   {
#    "name": "Kishan Karu",
#    "id": "1370846554"
#   },
#   {
#    "name": "Dao Duy Anh Duc",
#    "id": "1404518810"
#   },
#   {
#    "name": "Qu\u00e2n Quay Qu\u1ea7n",
#    "id": "1453599952"
#   },
#   {
#    "name": "\u0110\u00e0o Minh Quang",
#    "id": "1478409813"
#   },
#   {
#    "name": "Henry Geerlings",
#    "id": "1550028850"
#   },
#   {
#    "name": "Jody Zhang",
#    "id": "1561086925"
#   },
#   {
#    "name": "Michael Romain",
#    "id": "1603068573"
#   },
#   {
#    "name": "Duyen Truong",
#    "id": "1609728502"
#   },
#   {
#    "name": "Ann Johnson",
#    "id": "1612686765"
#   },
#   {
#    "name": "Jack Lin",
#    "id": "1620678313"
#   },
#   {
#    "name": "Trang Tran",
#    "id": "1673734693"
#   },
#   {
#    "name": "Tuan Anh Nguyen Dang",
#    "id": "1695141920"
#   },
#   {
#    "name": "Khoa Tran",
#    "id": "1695482266"
#   },
#   {
#    "name": "Ha Le",
#    "id": "1709278670"
#   },
#   {
#    "name": "Tj Dhadwal",
#    "id": "1719940978"
#   },
#   {
#    "name": "Chibi Pup",
#    "id": "1737559813"
#   },
#   {
#    "name": "Khang Nguyen Chi",
#    "id": "1781202325"
#   },
#   {
#    "name": "Nhan Thanh Nguyen",
#    "id": "1793056861"
#   },
#   {
#    "name": "Alex Chao",
#    "id": "1799108098"
#   },
#   {
#    "name": "Simon Shaolei Du",
#    "id": "1814033775"
#   },
#   {
#    "name": "Desiree Chow",
#    "id": "1818676009"
#   },
#   {
#    "name": "V\u00e2n Anh",
#    "id": "1819720378"
#   },
#   {
#    "name": "Tram Do",
#    "id": "1838154942"
#   },
#   {
#    "name": "Steven Belding",
#    "id": "100000027594757"
#   },
#   {
#    "name": "Khoi Tran",
#    "id": "100000062442563"
#   },
#   {
#    "name": "Nguyen Do",
#    "id": "100000065762888"
#   },
#   {
#    "name": "Ng\u00e2n Nguy\u1ec5n",
#    "id": "100000105240450"
#   },
#   {
#    "name": "Tuan Ho",
#    "id": "100000117790812"
#   },
#   {
#    "name": "Chidofukuto Rimokatoji",
#    "id": "100000124958582"
#   },
#   {
#    "name": "Tuan Doan",
#    "id": "100000125032625"
#   },
#   {
#    "name": "Amy PDang",
#    "id": "100000157489550"
#   },
#   {
#    "name": "Zee Pham",
#    "id": "100000163538217"
#   },
#   {
#    "name": "Henti Ogilecun",
#    "id": "100000174416983"
#   },
#   {
#    "name": "Neo Hung \u2267\u25e1\u2266",
#    "id": "100000195920629"
#   },
#   {
#    "name": "H\u1eb1ng Ph\u1ea1m",
#    "id": "100000417270253"
#   },
#   {
#    "name": "Kien Vinh Tu",
#    "id": "100000422166434"
#   },
#   {
#    "name": "Dang N. Le",
#    "id": "100000429914114"
#   },
#   {
#    "name": "Kyle Yu",
#    "id": "100000431092546"
#   },
#   {
#    "name": "Kevin Huynh",
#    "id": "100000575192060"
#   },
#   {
#    "name": "Mana Nabati",
#    "id": "100000735903908"
#   },
#   {
#    "name": "Shannon Camacho",
#    "id": "100001040648747"
#   },
#   {
#    "name": "Wanh Lay",
#    "id": "100001072372174"
#   },
#   {
#    "name": "Phan Giap Hoang Huy",
#    "id": "100001077416922"
#   },
#   {
#    "name": "Jake Long Nguyen",
#    "id": "100001090617181"
#   },
#   {
#    "name": "T\u00fa Uy\u00ean",
#    "id": "100001096815369"
#   },
#   {
#    "name": "Toan Nguyen",
#    "id": "100001128228421"
#   },
#   {
#    "name": "Bryanna Reed",
#    "id": "100001148899490"
#   },
#   {
#    "name": "Stephen Huang",
#    "id": "100001152574782"
#   },
#   {
#    "name": "Qu\u00e2n Nguy\u1ec5n",
#    "id": "100001267212483"
#   },
#   {
#    "name": "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#    "id": "100001432923607"
#   },
#   {
#    "name": "David Bui",
#    "id": "100001435855255"
#   },
#   {
#    "name": "Liz Huynh",
#    "id": "100001547031600"
#   },
#   {
#    "name": "Van Dang",
#    "id": "100001566973472"
#   },
#   {
#    "name": "Hil Alsibai",
#    "id": "100001611775489"
#   },
#   {
#    "name": "Weier Wan",
#    "id": "100002080435581"
#   },
#   {
#    "name": "Ntd Thuy",
#    "id": "100002292264586"
#   },
#   {
#    "name": "Stanley Yang",
#    "id": "100002761671363"
#   },
#   {
#    "name": "Giovanni Morgan",
#    "id": "100003261376442"
#   },
#   {
#    "name": "Ph\u01b0\u01a1ng Th\u1ea3o Nguy\u1ec5n",
#    "id": "100005868369540"
#   },
#   {
#    "name": "Trevor Davenport",
#    "id": "100006526336094"
#   },
#   {
#    "name": "Carl Shan",
#    "id": "100006763153362"
#   }
#  ]
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?type=page&q=social+web&access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&limit=5000&offset=5000&__after_id=239907479413081"
#  },
#  "data": [
#   {
#    "category": "Internet/software",
#    "name": "HostGator",
#    "id": "42249842091"
#   },
#   {
#    "category": "Internet/software",
#    "name": "HootSuite",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     },
#     {
#      "id": "152142351517013",
#      "name": "Corporate Office"
#     }
#    ],
#    "id": "177463958820"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Today",
#    "id": "18797601233"
#   },
#   {
#    "category": "Professional services",
#    "name": "HyperArts Web Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "75033592467"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Networking",
#    "id": "112063488819066"
#   },
#   {
#    "category": "Software",
#    "name": "Social Fixer",
#    "id": "174424289341"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "YO SOY DE SAN MARTIN",
#    "category_list": [
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     },
#     {
#      "id": "108557642554592",
#      "name": "Educational Service"
#     },
#     {
#      "id": "161422927240513",
#      "name": "Government Organization"
#     }
#    ],
#    "id": "188227341458"
#   },
#   {
#    "category": "Website",
#    "name": "SocialMouths",
#    "id": "76923634490"
#   },
#   {
#    "category": "Product/service",
#    "name": "Facebook",
#    "id": "20531316728"
#   },
#   {
#    "category": "Public figure",
#    "name": "Mark Zuckerberg",
#    "id": "112845672063384"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Qualium Web M\u00e9rida",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "77746598833"
#   },
#   {
#    "category": "Software",
#    "name": "North Social",
#    "category_list": [
#     {
#      "id": "2211",
#      "name": "Software"
#     }
#    ],
#    "id": "247440288175"
#   },
#   {
#    "category": "News/media website",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Internet/software",
#    "name": "GroSocial",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "120638286692"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Mashable",
#    "id": "18807449704"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "SocialBo - Web Design and Social Media Online Presence For Small Businesses",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "475997555787520"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Fixer Development",
#    "id": "119314224763738"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Say It Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "69634844497"
#   },
#   {
#    "category": "Politician",
#    "name": "Imran Khan (official)",
#    "id": "143462899029472"
#   },
#   {
#    "category": "Internet/software",
#    "name": "22Social",
#    "category_list": [
#     {
#      "id": "358483060859947",
#      "name": "Startup"
#     }
#    ],
#    "id": "107894379351327"
#   },
#   {
#    "category": "Local business",
#    "name": "etrade.ba | Social Media & Web",
#    "id": "217376194979375"
#   },
#   {
#    "category": "Actor/director",
#    "name": "David Tennant",
#    "id": "16178305388"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Domino's Pizza",
#    "id": "6657899956"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Profits",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "166707329019"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Chipotle Mexican Grill",
#    "id": "124149619252"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "The Social Media Web Genie",
#    "id": "537321239622767"
#   },
#   {
#    "category": "Product/service",
#    "name": "NVIDIA",
#    "id": "8409118252"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Bank/financial institution",
#    "name": "GTBank",
#    "id": "112969359130"
#   },
#   {
#    "category": "Camera/photo",
#    "name": "Socialcam",
#    "id": "174048665959409"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Kinnect",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "180032872071764"
#   },
#   {
#    "category": "Website",
#    "name": "Social Translation \"Conyac\"",
#    "id": "137288463876"
#   },
#   {
#    "category": "Product/service",
#    "name": "Boeing Careers",
#    "id": "176187689062463"
#   },
#   {
#    "category": "Political party",
#    "name": "Pakistan Tehreek-e-Insaf",
#    "id": "151626539526"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "SocialMediopolis.com",
#    "id": "273752592690671"
#   },
#   {
#    "category": "Professional services",
#    "name": "Impulsive Labs Web Design & Social Media Management",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "261688960613759"
#   },
#   {
#    "category": "Musician/band",
#    "name": "Dina El Wedidi",
#    "id": "130956663647835"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Networks",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "151931054869702",
#      "name": "Document Service"
#     }
#    ],
#    "id": "266641420128830"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Interest",
#    "name": "Social media marketing",
#    "id": "112759865404595"
#   },
#   {
#    "category": "Website",
#    "name": "Orkut",
#    "id": "103979926305987"
#   },
#   {
#    "category": "Movie",
#    "name": "The Social Network",
#    "id": "170585432961792"
#   },
#   {
#    "category": "Musician/band",
#    "name": "Immortal",
#    "id": "7973092317"
#   },
#   {
#    "category": "Musician/band",
#    "name": "Take That",
#    "id": "10096734918"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialNotz.com",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "416567388397595"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Catapult",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "192021210817573",
#      "name": "Public Relations"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "351244568233842"
#   },
#   {
#    "category": "News/media website",
#    "name": "Digital Buzz",
#    "id": "295279160577"
#   },
#   {
#    "category": "Website",
#    "name": "Raptr",
#    "id": "108217345865489"
#   },
#   {
#    "category": "Magazine",
#    "name": "Social Tech News",
#    "id": "303645613037168"
#   },
#   {
#    "category": "Local business",
#    "name": "Allographics Web & Social Media Design Solutions",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "181729338411"
#   },
#   {
#    "category": "Website",
#    "name": "Google+",
#    "id": "184079844991962"
#   },
#   {
#    "category": "Insurance company",
#    "name": "Prudential Indonesia (Official Fan Page)",
#    "id": "198348836882416"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Contractors",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "205791126146689"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media SF",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "123091234429113"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Quickstarter",
#    "id": "202780539757809"
#   },
#   {
#    "category": "App page",
#    "name": "Static Html - Thunderpenny",
#    "id": "237278599679568"
#   },
#   {
#    "category": "Church/religious organization",
#    "name": "Mormon.org",
#    "id": "469931643049786"
#   },
#   {
#    "category": "Local business",
#    "name": "SocialMX Web | Marketing | Eventos",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "101466069892291"
#   },
#   {
#    "category": "Games/toys",
#    "name": "Zynga RewardVille",
#    "id": "184192701612211"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Networking Nanny",
#    "id": "121612770066"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialMedia Designs",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "173876899342866"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Energy",
#    "id": "322192858925"
#   },
#   {
#    "category": "Public figure",
#    "name": "Social Media Fairy Godmother",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "201528873201605",
#      "name": "Management Service"
#     }
#    ],
#    "id": "133311290181319"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Media Power",
#    "id": "307566769315197"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "76277666156"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Kreativevue Web Design & Social Media",
#    "id": "426710170752907"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Focus by Cheryl Gnad",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "210845382278690"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Agency",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "179507378740391"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Rehab",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "425879530782550"
#   },
#   {
#    "category": "Company",
#    "name": "Viewmy.tv Social Media Network",
#    "id": "176745659017692"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Contest List",
#    "id": "124113204347180"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Capitalize Social",
#    "id": "360452374031854"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Fans Expert",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "125537380882060"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Apps: Like Our Business",
#    "id": "174598439222670"
#   },
#   {
#    "category": "News/media website",
#    "name": "Advertising on the Web",
#    "id": "28705232393"
#   },
#   {
#    "category": "Website",
#    "name": "RedFlag News",
#    "id": "116727628853"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Guardian",
#    "id": "191148684270081"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Instant Social Media",
#    "id": "195700407131405"
#   },
#   {
#    "category": "Business services",
#    "name": "PresentationMultimedia - Social Media, SEO, DVD & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "173932019310961"
#   },
#   {
#    "category": "Company",
#    "name": "Sweden Social Web Camp",
#    "id": "290284817827"
#   },
#   {
#    "category": "Product/service",
#    "name": "The Social Media People",
#    "category_list": [
#     {
#      "id": "2201",
#      "name": "Product/Service"
#     }
#    ],
#    "id": "136611456394014"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialTransactions",
#    "id": "145053695511877"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Butterfly Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "123922515951"
#   },
#   {
#    "category": "Personal blog",
#    "name": "SocialStepfanie",
#    "id": "112841935395224"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media AE",
#    "id": "463218157029101"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Market Buzz",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "343389599074949"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Community",
#    "name": "SocialDesignBucket",
#    "id": "177025039017543"
#   },
#   {
#    "category": "Education",
#    "name": "Social Media Marketing & Web Communication - Executive Master SDC IULM",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "104917969542058"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Viper",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "219749994713183"
#   },
#   {
#    "category": "Product/service",
#    "name": "SocialWorkJobBank Career Center",
#    "id": "24632132273"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Dentist",
#    "id": "115112122205"
#   },
#   {
#    "category": "Software",
#    "name": "ShortStack",
#    "id": "152695104762430"
#   },
#   {
#    "category": "Professional services",
#    "name": "Elliottsweb - Website Design, SEO and Social Media Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "324412657671756"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Summerville Social",
#    "id": "127634784061910"
#   },
#   {
#    "category": "Professional sports team",
#    "name": "Cricket Canada",
#    "category_list": [
#     {
#      "id": "1801",
#      "name": "Professional Sports Team"
#     }
#    ],
#    "id": "193658088359"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "HDA Web Design",
#    "id": "536508116384556"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Hero Network",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "31011001115"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "J Campbell Social Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "277920658904009"
#   },
#   {
#    "category": "App page",
#    "name": "MeSocial",
#    "id": "534894303189340"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "The Baltimore Sun",
#    "category_list": [
#     {
#      "id": "108366235907857",
#      "name": "Newspaper"
#     }
#    ],
#    "id": "9299179711"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Media Airwaves",
#    "id": "412780008778376"
#   },
#   {
#    "category": "App page",
#    "name": "Conduit",
#    "id": "19425413520"
#   },
#   {
#    "category": "Company",
#    "name": "GOfreshers",
#    "category_list": [
#     {
#      "id": "108557642554592",
#      "name": "Educational Service"
#     },
#     {
#      "id": "191684877517919",
#      "name": "Publisher"
#     },
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     }
#    ],
#    "id": "365122633557404"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Make This Social",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "372602549455008"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Your Social Media Mogul",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "202874603067085"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "webfeuer - Social Media und mehr!",
#    "id": "369613539636"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialLeadsNow.com",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "278288122210658"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Juice Media",
#    "id": "272721876095888"
#   },
#   {
#    "category": "Company",
#    "name": "Growing Social Biz",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "101058213321162"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Elliottsweb | Miami Website Design | SEO | Social Media Experts",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "222342297805673"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Elite",
#    "id": "247213218703911"
#   },
#   {
#    "category": "Professional services",
#    "name": "BLAZE, a Social Media Firm",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "414502301934808"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Welborn Social Media",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "284581981552203"
#   },
#   {
#    "category": "News/media website",
#    "name": "Salsa Con Estilo ((( www.salsaconestilo.com ))) LA COMUNIDAD SALSERA",
#    "id": "51443993470"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Butterfly Live",
#    "id": "451247084916919"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Networks",
#    "id": "115742145103272"
#   },
#   {
#    "category": "Product/service",
#    "name": "Enchanting Social Media",
#    "id": "156283797774024"
#   },
#   {
#    "category": "Church/religious organization",
#    "name": "Kirche im Web 2.0 / Social Media",
#    "id": "161519650568794"
#   },
#   {
#    "category": "Professional services",
#    "name": "Limitless Social Media Management & Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "358076844231190"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Schweiz",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "138786412804715"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "MySocialWeb.nl",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "389545474484483"
#   },
#   {
#    "category": "Website",
#    "name": "Kitchen Sink Inc. -   Brand Evangelists. Web Social Strategy",
#    "id": "113034488902771"
#   },
#   {
#    "category": "Company",
#    "name": "AnthillSocial",
#    "id": "313375435378326"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialAdr - Social Bookmarking Community Service",
#    "id": "130186451107"
#   },
#   {
#    "category": "News/media website",
#    "name": "Salem County Social",
#    "id": "435994769826229"
#   },
#   {
#    "category": "Business services",
#    "name": "Ceebo",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "463799843652466"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Inbound Now",
#    "id": "171039972933925"
#   },
#   {
#    "category": "Product/service",
#    "name": "The Social Exchange",
#    "id": "415893981851251"
#   },
#   {
#    "category": "Website",
#    "name": "SpadeSocial",
#    "id": "229014417113524"
#   },
#   {
#    "category": "Recreation/sports website",
#    "name": "Smoking-Meat.com",
#    "category_list": [
#     {
#      "id": "2710",
#      "name": "Recreation/Sports Website"
#     }
#    ],
#    "id": "151381833804"
#   },
#   {
#    "category": "Local business",
#    "name": "Bacon Social Media Marketing - Baton Rouge",
#    "category_list": [
#     {
#      "id": "273819889375819",
#      "name": "Restaurant"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "223083117703325"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ApnaCircle",
#    "id": "213373065405347"
#   },
#   {
#    "category": "Professional services",
#    "name": "2010media",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "127917567250988"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Tweak'd Social",
#    "id": "585441408135713"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Tenddo.com \u00b7 Web Development \u00b7 Mobile App \u00b7 Social Media Solutions",
#    "id": "240871466067663"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Hippocampus Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "310698660379"
#   },
#   {
#    "category": "Interest",
#    "name": "Instagram",
#    "id": "219027581449094"
#   },
#   {
#    "category": "Product/service",
#    "name": "Improve Your Social Media Performance",
#    "id": "295079290593817"
#   },
#   {
#    "category": "Actor/director",
#    "name": "Andrew Lincoln",
#    "id": "268334903255433"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SEOLaws.com - SEO . PPC . Social Media . Web Design . Video . NonProfits",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "185123218198865"
#   },
#   {
#    "category": "Organization",
#    "name": "Twiter",
#    "id": "111804865511881"
#   },
#   {
#    "category": "Internet/software",
#    "name": "iSTUDIO",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "137440869848"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Media Marketing Dubai",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "103778059813717"
#   },
#   {
#    "category": "Website",
#    "name": "Laura Lam Ortiz - Social Media Marketing & Management",
#    "id": "128462317257954"
#   },
#   {
#    "category": "Business services",
#    "name": "My Business Social Media Matters",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "138376892890599"
#   },
#   {
#    "category": "Website",
#    "name": "Mango Social Media",
#    "id": "415414651803910"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social Ratchet",
#    "id": "188744651262324"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "Shop Social",
#    "id": "295128667280818"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Orb Social Media Strategy",
#    "id": "432904290063319"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "CB Social Media Marketing",
#    "id": "152921651576697"
#   },
#   {
#    "category": "Business services",
#    "name": "Extreme Social Media",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "262103140470885"
#   },
#   {
#    "category": "Just for fun",
#    "name": "Southern Pinning",
#    "id": "469540973113141"
#   },
#   {
#    "category": "Product/service",
#    "name": "Curso de Social Media y Marketing Online",
#    "id": "250670968319846"
#   },
#   {
#    "category": "Organization",
#    "name": "Dodgeball (service)",
#    "id": "108414455846611"
#   },
#   {
#    "category": "News/media website",
#    "name": "C4N - Come4News - Le m\u00e9dia social citoyen",
#    "category_list": [
#     {
#      "id": "108366235907857",
#      "name": "Newspaper"
#     }
#    ],
#    "id": "17411804369"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Let's Go Social",
#    "id": "379275762163959"
#   },
#   {
#    "category": "Government organization",
#    "name": "Gobierno de la Provincia de Buenos Aires",
#    "category_list": [
#     {
#      "id": "161422927240513",
#      "name": "Government Organization"
#     }
#    ],
#    "id": "112495102121367"
#   },
#   {
#    "category": "Local business",
#    "name": "Vahid Esteghamat",
#    "category_list": [
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     },
#     {
#      "id": "166419966738430",
#      "name": "DJ"
#     },
#     {
#      "id": "189483194405517",
#      "name": "Music Production"
#     }
#    ],
#    "id": "367160926718915"
#   },
#   {
#    "category": "Business services",
#    "name": "Purple Monkey Social Media Marketing",
#    "id": "359632517406943"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Circus Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "575042275846072"
#   },
#   {
#    "category": "Product/service",
#    "name": "Internet Marketing & Social Media",
#    "id": "171665382889105"
#   },
#   {
#    "category": "Local business",
#    "name": "Social-Media",
#    "id": "172523566157914"
#   },
#   {
#    "category": "Community",
#    "name": "European Youth Portal- A European Social Network?",
#    "id": "126620747417619"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "FullCircle GeoSocial Network, Inc.",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "283561971762218"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "AboutMe 247 Social Media",
#    "id": "191143220984445"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "VizionOnline",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "104435882942766"
#   },
#   {
#    "category": "Cause",
#    "name": "Stand Up For WWE",
#    "id": "116414378418467"
#   },
#   {
#    "category": "Organization",
#    "name": "Tumblr",
#    "id": "108169805870137"
#   },
#   {
#    "category": "Internet/software",
#    "name": "55social",
#    "category_list": [
#     {
#      "id": "198503866828628",
#      "name": "Organization"
#     }
#    ],
#    "id": "253255464708036"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Bee Social",
#    "id": "180012895477291"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Susan Critelli - Making Business More Personal",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "82791504262"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Amkette - Digital Life Redefined",
#    "id": "157234327665080"
#   },
#   {
#    "category": "Company",
#    "name": "Pazhampori Media",
#    "id": "190178651125316"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Adda",
#    "id": "708250389204472"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Local business",
#    "name": "So Crafty Social Media / Web Design / PR",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "225944470853448"
#   },
#   {
#    "category": "App page",
#    "name": "777 Social Media",
#    "id": "439002776182128"
#   },
#   {
#    "category": "Song",
#    "name": "Lorie",
#    "id": "15439988778"
#   },
#   {
#    "category": "Company",
#    "name": "Enova4U Dise\u00f1o Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "218721764817225"
#   },
#   {
#    "category": "Internet/software",
#    "name": "My SEO Guys",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "375302132597557"
#   },
#   {
#    "category": "Musician/band",
#    "name": "Michael Jackson Fans Club Argentina Y El Mundo(Oficial)",
#    "id": "159519720727744"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Pi\u00f9 - Social Media Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "264261473614294"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Rostin Ventures Social Media Marketing Mobile SEO Agency",
#    "id": "184435061585831"
#   },
#   {
#    "category": "Company",
#    "name": "Business Thinking Web 2.0",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "116606555063865"
#   },
#   {
#    "category": "Product/service",
#    "name": "andyalagappan.com",
#    "id": "138943366147238"
#   },
#   {
#    "category": "Website",
#    "name": "TechnoBuffalo",
#    "id": "107855142579272"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Votigo Social Media Solutions",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "30234388700"
#   },
#   {
#    "category": "Health/wellness website",
#    "name": "SocialCooking",
#    "id": "129279477124211"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "BA-MultiMedia Groupe",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "416474841726051"
#   },
#   {
#    "category": "Company",
#    "name": "Life Social Network",
#    "category_list": [
#     {
#      "id": "124994474239211",
#      "name": "Amusement"
#     }
#    ],
#    "id": "425079837583397"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Evam Technologies",
#    "id": "149808078420617"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Magazine",
#    "id": "202163419911377"
#   },
#   {
#    "category": "Actor/director",
#    "name": "Emily Browning (OFFICIAL)",
#    "id": "196848520352180"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Marketing News",
#    "id": "128957153933846"
#   },
#   {
#    "category": "Government organization",
#    "name": "MIURSocial - partecipazione e trasparenza  made in MIUR",
#    "category_list": [
#     {
#      "id": "161422927240513",
#      "name": "Government Organization"
#     }
#    ],
#    "id": "100924280069563"
#   },
#   {
#    "category": "Internet/software",
#    "name": "909c - social graph designers",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "192543047187"
#   },
#   {
#    "category": "Internet/software",
#    "name": "\u05e8\u05d9\u05e4\u05e8\u05e9 - Refresh",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "8638138401"
#   },
#   {
#    "category": "Professional services",
#    "name": "Codesky Web Design & Social Media",
#    "id": "278298328945358"
#   },
#   {
#    "category": "Interest",
#    "name": "Skyrock (social network site)",
#    "id": "106122586085473"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialTrade24",
#    "id": "263816810352008"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Matrix",
#    "id": "222527314458980"
#   },
#   {
#    "category": "Magazine",
#    "name": "Fires Bulletin",
#    "id": "277937334138"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Stanford Media Marketing",
#    "id": "390962477689105"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialGO",
#    "id": "100751075292"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Strut",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "150974525087565"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Zing - your social store",
#    "category_list": [
#     {
#      "id": "200600219953504",
#      "name": "Shopping & Retail"
#     }
#    ],
#    "id": "147081832081503"
#   },
#   {
#    "category": "Product/service",
#    "name": "Malaysia Social Media Marketing",
#    "id": "480806711994715"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Plugin Social Media",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "349063295125319"
#   },
#   {
#    "category": "App page",
#    "name": "MySocialColor",
#    "id": "405583766162721"
#   },
#   {
#    "category": "Business services",
#    "name": "Drive Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "155873241210106"
#   },
#   {
#    "category": "Internet/software",
# ...
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "226277557526409"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "\u062a\u0639\u0644\u0645 \u0627\u0644\u0634\u0628\u0643\u0627\u062a \u0627\u0644\u0627\u062c\u062a\u0645\u0627\u0639\u064a\u0647",
#    "id": "117728265015590"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Extremo",
#    "id": "308199265930630"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "MC Social Agency",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "193705277324704",
#      "name": "Event Planning"
#     }
#    ],
#    "id": "162915013906447"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "LogmeOnce",
#    "id": "268654433251140"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "StartUp Social Network",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "544303772279544"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Dana Agency SARL",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "269480909826154"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Ethical Havoc",
#    "id": "164376860399767"
#   },
#   {
#    "category": "Professional services",
#    "name": "SNAP-Social Media Marketing/Web Design",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "492285150843542"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Networking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "107250802682991"
#   },
#   {
#    "category": "Website",
#    "name": "Sovedo",
#    "id": "322269427821245"
#   },
#   {
#    "category": "Professional services",
#    "name": "Seo Smo India",
#    "id": "280260838759485"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "maccom | be social",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "179027822128298"
#   },
#   {
#    "category": "Local business",
#    "name": "Harlo Interactive",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "71819621048"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Mai Dire Social",
#    "id": "155481631290658"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Vision Media",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "171022959595127"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "DCarlyle Social Media Management",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "353436981450006"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "MasseyMedia, Inc. - Web Design and Social Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "105451942867889"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Sysmaya Blog Social",
#    "id": "154409857909355"
#   },
#   {
#    "category": "Local business",
#    "name": "Shoreline Media Marketing Design. SEO, SEM, Social Media & More.",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "362511880785"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Driver",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "173652409354108"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Agryd.com",
#    "id": "330272180329026"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social World Ecuador",
#    "id": "626499010712993"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Speak Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "127692573953699"
#   },
#   {
#    "category": "Professional services",
#    "name": "RedHot Design | Web Designers + Social Media Strategists",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "100306133360993"
#   },
#   {
#    "category": "Professional services",
#    "name": "Apps For Digital Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "438744426205858"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Development Trends",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "156420394543268"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Moxy Inc.",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "181810911869945"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Drive Digital Group",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "210070935740062"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Scoop Advertising",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "426294560764897"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "El Paso Times",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "115612465136194"
#   },
#   {
#    "category": "Website",
#    "name": "Giiaa.com Dise\u00f1o Posicionamiento Web",
#    "id": "1413817922165399"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Mukulfreelancer",
#    "id": "331746600287193"
#   },
#   {
#    "category": "Community organization",
#    "name": "Foro TodoTrabajoSocial",
#    "id": "402703099797135"
#   },
#   {
#    "category": "Local business",
#    "name": "City of Melbourne",
#    "category_list": [
#     {
#      "id": "161422927240513",
#      "name": "Government Organization"
#     }
#    ],
#    "id": "209720392384537"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SOCIOPAL",
#    "category_list": [
#     {
#      "id": "200600219953504",
#      "name": "Shopping & Retail"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "221897361206513"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social House Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "235468493149584"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Panty",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "226168080822474"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Marketing Agency",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "582088421801254"
#   },
#   {
#    "category": "Company",
#    "name": "BSocial",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "133669593358394"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "First Group 2.0 Social Media Consulting",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "474111792657142"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Open Designs ( Discuss. Design. Deliver)",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "195689873799264"
#   },
#   {
#    "category": "Business person",
#    "name": "Paul Haley - Web Design and Social Media",
#    "id": "229853217188491"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWire",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "179070542137067"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Freelancer Services",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "525407044203240"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Digital 2 Social Media S.L.",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "281152735311561"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Media Titans",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "125212857514131"
#   },
#   {
#    "category": "Product/service",
#    "name": "Pr-Band Kibergramota",
#    "id": "152017778331490"
#   },
#   {
#    "category": "Book",
#    "name": "Be Safety From Online Relationship",
#    "id": "306304929498516"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Law Library",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "159684454098254"
#   },
#   {
#    "category": "Arts/humanities website",
#    "name": "ARTISTEO : le r\u00e9seau social professionnel de l'art",
#    "id": "174094349276102"
#   },
#   {
#    "category": "Tv show",
#    "name": "myzimbabwe.co.zw",
#    "id": "222294537801970"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Top Team",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "115004558693889"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "LR social media",
#    "id": "116270498520528"
#   },
#   {
#    "category": "Entertainer",
#    "name": "Christine Mendoza",
#    "id": "397702070248828"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Multibrain",
#    "category_list": [
#     {
#      "id": "358483060859947",
#      "name": "Startup"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "152142351517013",
#      "name": "Corporate Office"
#     }
#    ],
#    "id": "297253330136"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Club Antwerpen",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "222478201146564"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Dise\u00f1o de P\u00e1ginas Web en Colombia y Posicionamiento SEO Web Dweb3d.com",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "100777103320586"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Cardinal Web Solutions",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "96832772061"
#   },
#   {
#    "category": "Professional services",
#    "name": "All Web Solutionz",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "494277220643157"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Techtunes",
#    "id": "323434175373"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Loompad",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "563202437056338"
#   },
#   {
#    "category": "Internet/software",
#    "name": "\u09ab\u09c7\u09b8\u09ac\u09c1\u0995 \u099f\u09bf\u09aa\u09b8",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "376914739069826"
#   },
#   {
#    "category": "Company",
#    "name": "REX Social TV",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "1378405422400706"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Learning Project",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "239907479413081"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "category": "Book",
#  "username": "MiningTheSocialWeb",
#  "about": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites. Twitter: @SocialWebMining",
#  "talking_about_count": 76,
#  "description": "Facebook, Twitter, LinkedIn, Google+, and other social web properties generate a wealth of valuable social data, but how can you tap into this data and discover who\u2019s connecting with whom, which insights are lurking just beneath the surface, and what people are talking about? This book shows you how to answer these questions and many more. Each chapter combines popular and useful social web data with analysis techniques and visualization to help you find the needles in the social haystack that you've been looking for\u2014as well as many you probably didn't even know existed.\n\nIn this expanded and thoroughly revised second edition you\u2019ll learn how to:\n\n* Navigate the most popular social web APIs to access, collect, analyze, and visualize social web data\n* Employ IPython Notebook and other easy to use Python packages such as the Natural Language Toolkit, NetworkX, and Matplotlib to efficiently sift through social web data as part of an experimentally-driven approach to discovering insights in social web data\n* Apply advanced text-mining techniques such as TF-IDF, cosine similarity, collocation analysis, document summarization, and clique detection to human language data that you'll encounter all over the web\n* Bootstrap interest graphs by discovering latent affinities between people, programming languages, and coding projects from GitHub data\n* Visualize social web data with D3, a state-of-the-art HTML5 and JavaScript toolkit\n\nThe book's source code is maintained in a GitHub repository maintained by the author and can be deployed as turn-key virtual machine with each chapter's source code presented in an interactive and easy to use IPython Notebook format. No complex third-party installations or advanced Python knowledge is required to get the most out of this book.",
#  "company_overview": "Like It here on Facebook!\n\nFollow @SocialWebMining on Twitter: http://twitter.com/SocialWebMining\n\nGet the source code for the revised and expanded second edition on GitHub: http://bit.ly/MiningTheSocialWeb2E\n\nGet the (now legacy) source code for the first edition on GitHub: http://bit.ly/SocialWebMining",
#  "release_date": "January 2011",
#  "can_post": true,
#  "cover": {
#   "source": "https://scontent-a.xx.fbcdn.net/hphotos-ash3/s720x720/1003733_522831997772034_741301400_n.jpg",
#   "cover_id": 522831997772034,
#   "offset_x": 0,
#   "offset_y": 56
#  },
#  "mission": "Teaches you how to navigate the most popular social web APIs to access, collect, analyze, and visualize social web data with IPython Notebook and other easy to use Python packages and visualization tools.",
#  "website": "http://miningthesocialweb.com",
#  "name": "Mining the Social Web",
#  "founded": "January 2011",
#  "awards": "Jolt Productivity Award (1st Ed.) -  http://drdobbs.com/joltawards/231500080?pgno=6",
#  "likes": 1335,
#  "were_here_count": 0,
#  "genre": "Data Mining",
#  "link": "https://www.facebook.com/MiningTheSocialWeb",
#  "general_info": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites - Get it at http://bit.ly/135dHfs",
#  "id": "146803958708175",
#  "is_published": true
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 188
# }
# {
#  "category": "Book",
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "can_post": true,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "likes": 18,
#  "were_here_count": 0,
#  "id": "221689464577245",
#  "is_published": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?limit=5&type=page&q=pepsi&access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&offset=5&__after_id=112402755453388"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi",
#    "id": "56381779049"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "200019523363001",
#      "name": "Food & Beverage Service & Distribution"
#     }
#    ],
#    "id": "260431051694"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Philippines",
#    "id": "400886490082"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Masr",
#    "id": "179520928732783"
#   },
#   {
#    "category": "Product/service",
#    "name": "Pepsi",
#    "id": "112402755453388"
#   }
#  ]
# }
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?limit=5&type=page&q=coke&access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&offset=5&__after_id=205095305258"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola",
#    "id": "40796308305"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio",
#    "category_list": [
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     }
#    ],
#    "id": "16944632531"
#   },
#   {
#    "category": "Food",
#    "name": "Chocolate",
#    "id": "113472061996206"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coke Studio \u0628\u0627\u0644\u0639\u0631\u0628\u064a",
#    "id": "343815695662228"
#   },
#   {
#    "category": "Musician/band",
#    "name": "coke bust",
#    "id": "205095305258"
#   }
#  ]
# }
# Pepsi likes:
# 29,146,924
# Coke likes:
# 77,009,315

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pepsi_id = '266736903421190'
pp(g.get_connections(pepsi_id, 'feed'))
#pp(g.get_connections(pepsi_id, 'links'))

#pp(g.get_connections(coke_id, 'feed'))
#pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/266736903421190/feed?access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&limit=25&until=1386266907&__paging_token=266736903421190_565316850229859",
#   "previous": "https://graph.facebook.com/266736903421190/feed?access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&limit=25&since=1386717558&__paging_token=266736903421190_567684553326422&__previous=1"
#  },
#  "data": [
#   {
#    "from": {
#     "name": "Molly Nicholas",
#     "id": "62601103"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567684553326422",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567684553326422",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T23:19:18+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTA4Nzg5MDQyMQ==",
#       "before": "MTQ0MTYxMDIyOA=="
#      }
#     },
#     "data": [
#      {
#       "id": "1441610228",
#       "name": "Jeff Pak"
#      },
#      {
#       "id": "730212014",
#       "name": "Alex Thomas Ren"
#      },
#      {
#       "id": "518566844",
#       "name": "Ronak Vora"
#      },
#      {
#       "id": "1087890421",
#       "name": "Eric Kim"
#      }
#     ]
#    },
#    "created_time": "2013-12-09T19:03:22+0000",
#    "message": "Anyone know what the downsides of getting a \"NP\" (no pass) in a .5-unit PE class are?  Like I know it'll show up on my transcript but I'm trying to figure out who would care....I just really don't want to go to yoga right now.",
#    "type": "status",
#    "id": "266736903421190_567684553326422",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY4MjQ3NTE5OTM2Nzky",
#       "before": "NTY3Njg2NDMzMzI2MjM0"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "David Huang",
#        "id": "692240653"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:08:12+0000",
#       "message": "They will ask you to demonstrate that you can be productive sitting on an exercise ball.",
#       "id": "567686433326234",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "YJ Yang",
#        "id": "100000873085800"
#       },
#       "like_count": 59,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:08:48+0000",
#       "message": "you can claim P=NP",
#       "id": "567686586659552",
#       "user_likes": true
#      },
#      {
#       "from": {
#        "name": "Eric Kim",
#        "id": "1087890421"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:11:05+0000",
#       "message": "Haha. Well, unless you're sick, I'd recommend going! In case you apply to grad school, you'd like to avoid any raised eyebrows (even though this NP is for a class that isn't a bit deal, it might raise some red flags in admission systems).\n\nBasically: uu-unexpeected coo-onsequences! *spooky voice*",
#       "id": "567687306659480",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Molly Nicholas",
#        "id": "62601103"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:12:40+0000",
#       "message": "I'm also not sure if I'll even get an NP.... (I'm pretty sure classes aren't allowed to meet during dead week?) it's just the worst-case scenario.....\n\nUghh........",
#       "id": "567687753326102",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Molly Nicholas",
#        "id": "62601103"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:16:27+0000",
#       "message": "But... yeah... you raise a good point.",
#       "id": "567688883325989",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Molly Nicholas",
#        "id": "62601103"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:22:21+0000",
#       "message": "Dammit",
#       "id": "567690613325816",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Matt Orzechowski",
#        "id": "100000670167218"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:35:32+0000",
#       "message": "Do Grad schools count P/NP only classes the same as they would unit classes taken as P/NP?",
#       "id": "567695719991972",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Shiyun Jane Huang",
#        "id": "1761169031"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:51:12+0000",
#       "message": "Gosh, I've NP a two-unit PE class before... Christopher said it has no effects for graduating from Berkeley, so I ignore it... seems not to be a good idea :(",
#       "id": "567701219991422",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Vivian Huiting Zheng",
#        "id": "1357364228"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T20:06:10+0000",
#       "message": "I think you can do a remove np petition next semester..I am doing two NP on self-paced classes this semester..dunno if it is still going to be shown on the transcript after you remove",
#       "id": "567705646657646",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jerry Lung",
#        "id": "596823205"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-09T20:07:42+0000",
#       "message": "your future employers will be like yo wtf dis gurl is lazy she didnt go to yoga that one time oh hayle nawww",
#       "id": "567706029990941",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Molly Nicholas",
#        "id": "62601103"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-09T20:28:03+0000",
#       "message": "\"Physical Education, however, is not considered a performance- based class, according to a determination made by the Academic Senate Committee on Course of Instruction \u2013 as such, physical education course instructors cannot hold mandatory classes during RRR week.\" from here: http://www.dailycal.org/2013/04/30/reporting-dead-week-violations/\n\nBOOM.  NO PANTS FOR ME TODAY.",
#       "id": "567712933323584",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Molly Nicholas",
#        "id": "62601103"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-09T20:32:17+0000",
#       "message": "OH NO She sound out an email saying class is an \"evaluation\" which means it's allowed during dead week nooooooooooooo",
#       "id": "567714126656798",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jay Kong",
#        "id": "100000226582379"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T21:15:43+0000",
#       "message": "just suck it up and go",
#       "id": "567729026655308",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Michael Ball",
#        "id": "571866327"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-09T22:40:43+0000",
#       "message": "The rules for dead week classes are so funky...",
#       "id": "567759733318904",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Anand Lakshminarayan",
#        "id": "634362168"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T23:19:18+0000",
#       "message": "HAHAHA at YJ's comment",
#       "id": "568247519936792",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "picture": "https://fbcdn-photos-a-a.akamaihd.net/hphotos-ak-prn2/1455133_10152048304911508_2119331754_s.jpg",
#    "from": {
#     "name": "Hemant Bhonsle",
#     "id": "616076507"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY4MjQ3MjM2NjAzNDg3",
#       "before": "NTYzMzg0OTIwNDIzMDUy"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Kevin Liang",
#        "id": "624842774"
#       },
#       "like_count": 37,
#       "can_remove": false,
#       "created_time": "2013-12-01T10:06:25+0000",
#       "message": "",
#       "id": "563384920423052",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Trevor Davenport",
#        "id": "100006526336094"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-02T23:22:17+0000",
#       "message": "wait what",
#       "id": "564181323676745",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Daniel Rolandi",
#        "id": "1314576693"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2013-12-07T15:35:07+0000",
#       "message": "I... don't get it?",
#       "id": "566546246773586",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "John Satoshi Okahata",
#        "id": "806038010"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-08T05:13:13+0000",
#       "message": "You can't catch an error you don't think of?",
#       "id": "566844263410451",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Neal Lawton",
#        "id": "100000821163282"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T23:18:24+0000",
#       "message": "Catching an exception is okay, but doing something to fix it is better!",
#       "id": "568247236603487",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/563384307089780",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/563384307089780",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T23:18:24+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10152048304911508&set=gm.563384307089780&type=1&relevant_count=1",
#    "object_id": "10152048304911508",
#    "created_time": "2013-12-01T10:03:42+0000",
#    "message": "Slide from my OS class everyone should take a moment to read, especially if you are in the 61 series and just learning to program.",
#    "type": "photo",
#    "id": "266736903421190_563384307089780",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Tim Osterbuhr",
#     "id": "504078344"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/568162426611968",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/568162426611968",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T19:07:03+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "created_time": "2013-12-10T19:07:03+0000",
#    "message": "Airseed is offering a $[100*e] referral award for full-time summer or part-time spring interns. If you are interested in big data and working in downtown SF as a software engineering intern, or you know someone who is looking for a paid internship, then definitely send me a message. \n\nAirseed is a developer platform that supercharges authentication (single sign-on), consumer data, and consumer analytics for app developers and Fortune 500 companies. We are currently backed by Google Ventures and based in downtown SF.\n\nYou can contact me directly via email tim@airseed.com or send me a Facebook message.",
#    "type": "status",
#    "id": "266736903421190_568162426611968"
#   },
#   {
#    "from": {
#     "name": "James Maa",
#     "id": "691950036"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567853379976206",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567853379976206",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T16:13:04+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTY1NDc0NzIwMQ==",
#       "before": "MTUyNDcwNjM0Mw=="
#      }
#     },
#     "data": [
#      {
#       "id": "1524706343",
#       "name": "John Li"
#      },
#      {
#       "id": "742694868",
#       "name": "Zachary Zeleznick"
#      },
#      {
#       "id": "677515385",
#       "name": "Alice Oh"
#      },
#      {
#       "id": "538312121",
#       "name": "Paroma Varma"
#      },
#      {
#       "id": "1086986855",
#       "name": "Krishna Parashar"
#      },
#      {
#       "id": "100002281621441",
#       "name": "Jesse Collins"
#      },
#      {
#       "id": "682643079",
#       "name": "Magdalene Lim"
#      },
#      {
#       "id": "1654747201",
#       "name": "Kyle Ong"
#      }
#     ]
#    },
#    "created_time": "2013-12-10T03:30:24+0000",
#    "message": "Anyone have a previous Product Management internship? I'd like to chat whether I should do a Product Management or Software Engineer internship this summer",
#    "type": "status",
#    "id": "266736903421190_567853379976206",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY4MDkwMTk2NjE5MTkx",
#       "before": "NTY3ODUzODE2NjQyODI5"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Aleksandrina Stoyanova",
#        "id": "1340332255"
#       },
#       "message_tags": [
#        {
#         "length": 8,
#         "offset": 0,
#         "type": "user",
#         "id": "1224386090",
#         "name": "Amy Tsai"
#        },
#        {
#         "length": 8,
#         "offset": 10,
#         "type": "user",
#         "id": "675598365",
#         "name": "Anran Li"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T03:31:59+0000",
#       "message": "Amy Tsai, Anran Li",
#       "id": "567853816642829",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "JoJo Chan",
#        "id": "593259539"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T03:38:37+0000",
#       "message": "I have. I would strongly suggest that all else being equal, you should take the cs internship. You will have more doors later on vs. Taking a pm internship",
#       "id": "567855059976038",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Bharath Satheesh",
#        "id": "1524228267"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T04:15:46+0000",
#       "message": "I think pm will give u a bigger picture of the grand scheme of things :D",
#       "id": "567867199974824",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jong Yoon Daniel Park",
#        "id": "100002499929243"
#       },
#       "message_tags": [
#        {
#         "length": 8,
#         "offset": 0,
#         "type": "user",
#         "id": "720785533",
#         "name": "Andy Mah"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T04:30:16+0000",
#       "message": "Andy Mah",
#       "id": "567871386641072",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Eric Quach",
#        "id": "520842843"
#       },
#       "message_tags": [
#        {
#         "length": 9,
#         "offset": 0,
#         "type": "user",
#         "id": "593259539",
#         "name": "JoJo Chan"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T04:40:31+0000",
#       "message": "JoJo Chan what if you want to become a PM in the future? same suggestion?",
#       "id": "567874046640806",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Brittany Cheng",
#        "id": "618311320"
#       },
#       "like_count": 11,
#       "can_remove": false,
#       "created_time": "2013-12-10T08:51:53+0000",
#       "message": "I've done design and PM internships (I study EECS, yes I'm all over the place I know...). PM me (pun intended)",
#       "id": "567942156633995",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "JoJo Chan",
#        "id": "593259539"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T16:13:04+0000",
#       "message": "Feel free to pm me as well",
#       "id": "568090196619191",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Jordan Niell",
#     "id": "1613986461"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567591580002386",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567591580002386",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T08:07:43+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTE4NzU2NjQ1Ng==",
#       "before": "MTE4NzU2NjQ1Ng=="
#      }
#     },
#     "data": [
#      {
#       "id": "1187566456",
#       "name": "Pratyush Mishra"
#      }
#     ]
#    },
#    "created_time": "2013-12-09T15:39:41+0000",
#    "message": "Since the answer to my previous question appears to be a no:\n\nWould anyone in this group be interested in starting an anti-internet surveillance group at Berkeley?",
#    "type": "status",
#    "id": "266736903421190_567591580002386",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3OTMyMzAzMzAxNjQ3",
#       "before": "NTY3NjQ3MDU2NjYzNTA1"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Alex Thomas Ren",
#        "id": "730212014"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-09T17:22:10+0000",
#       "message": "Are you sure posting about this on facebook is the best idea?",
#       "id": "567647056663505",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T17:28:08+0000",
#       "message": "...Yes?",
#       "id": "567650363329841",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T17:28:47+0000",
#       "message": "I'm not starting a \"let's be cyber terrorists and hack the government\" org. I'm looking to start a public political activism group.",
#       "id": "567650739996470",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Alex Thomas Ren",
#        "id": "730212014"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-09T17:29:38+0000",
#       "message": "I mean, will you be finding these people for this group on Facebook?",
#       "id": "567651139996430",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T17:30:26+0000",
#       "message": "Oh. \n\nMeh, gotta start somewhere.",
#       "id": "567651893329688",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Achal Dave",
#        "id": "1214724553"
#       },
#       "like_count": 6,
#       "can_remove": false,
#       "created_time": "2013-12-09T18:01:49+0000",
#       "message": "psst i'd recommend starting this perhaps at the beginning of next semester, or at least posting again then -- this is an incredibly busy time for many people who might be interested but don't want to think about anything for the moment",
#       "id": "567665056661705",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T22:01:56+0000",
#       "message": "Good call. I was really just polling around for interest.",
#       "id": "567744189987125",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Peter Wu",
#        "id": "1417256890"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-10T08:07:43+0000",
#       "message": "You should follow in Richard Stallman's steps",
#       "id": "567932303301647",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Pratyush Mishra",
#     "id": "1187566456"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567888166639394",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567888166639394",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T06:18:28+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3ODk5NTk2NjM4MjUx",
#       "before": "NTY3ODg4MzI5OTcyNzEx"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Mehrdad Ni",
#        "id": "100001128747196"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-10T05:33:44+0000",
#       "message": "Nope.",
#       "id": "567888329972711",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "David Lau",
#        "id": "1131704067"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T06:17:50+0000",
#       "message": "I took it. Waste of time for a cs major. Prepare to learn nothing new",
#       "id": "567899396638271",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Pratyush Mishra",
#        "id": "1187566456"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T06:18:28+0000",
#       "message": "Hmmm thanks then haha",
#       "id": "567899596638251",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-10T05:33:03+0000",
#    "message": "Has anyone taken Stats 133? What is it like?",
#    "type": "status",
#    "id": "266736903421190_567888166639394"
#   },
#   {
#    "from": {
#     "name": "Abdull Hamud",
#     "id": "1024466975"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567754586652752",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567754586652752",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T05:19:09+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NTQyNjQxODE0",
#       "before": "NTQyNjQxODE0"
#      }
#     },
#     "data": [
#      {
#       "id": "542641814",
#       "name": "Alexander Wang"
#      }
#     ]
#    },
#    "created_time": "2013-12-09T22:29:30+0000",
#    "message": "I posted a video about how to preserve your Berkeley email and realized that down the line, it won't work. I'm terribly sorry for misleading you, I will make sure to post another video soon, and again I'm sorry.",
#    "type": "status",
#    "id": "266736903421190_567754586652752",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3ODg0Njk5OTczMDc0",
#       "before": "NTY3NzU2NzYzMzE5MjAx"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T22:33:43+0000",
#       "message": "Do the emails go away when you graduate? :/",
#       "id": "567756763319201",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Abdull Hamud",
#        "id": "1024466975"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T22:35:40+0000",
#       "message": "There's a way to have them forwarded to you and you'll be able to keep some sort of alumni.berkeley.edu address so you can maintain the Berkeley prestige in your emails. In a nutshell, when you graduate, go to this link:\n\nhttps://cal.berkeley.edu/\n\nThen there is a forwarding thing on the bottom",
#       "id": "567757416652469",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Gerald Leung",
#        "id": "1170234525"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-10T00:12:33+0000",
#       "message": "Well so far, it does seem to be working for me and I graduated in '10, so I thought the video was pretty useful (obviously)!",
#       "id": "567789299982614",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Randy Wei",
#        "id": "100001507477935"
#       },
#       "message_tags": [
#        {
#         "length": 6,
#         "offset": 0,
#         "type": "user",
#         "id": "1170234525",
#         "name": "Gerald"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T02:54:23+0000",
#       "message": "Gerald, in your case you're lucky, because they did the conversion thing AFTER you graduated. Some new policies might not apply to you. That's like some grandfathered benefits. But for students who have not graduated yet, it won't work because the new system will make sure to delete the accounts belong to anyone who is no longer registered for nine months, and the authentication will then fail. But that video is beneficial to the ones who want to use bMail more easily and to save all conversations permanently.",
#       "id": "567843276643883",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Randy Wei",
#        "id": "100001507477935"
#       },
#       "message_tags": [
#        {
#         "length": 6,
#         "offset": 0,
#         "type": "user",
#         "id": "1613986461",
#         "name": "Jordan"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T03:02:19+0000",
#       "message": "Jordan, your bMail account will be deleted nine months after you're no longer affiliated with Cal. But if you graduate,  during that grace period, you have the option to keep your @berkeley.edu address forever by converting it to a forwarding address, but then you might not be able to send it from berkeley.edu domain, and that's how Abdull's video can help you.",
#       "id": "567845529976991",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Abdull Hamud",
#        "id": "1024466975"
#       },
#       "message_tags": [
#        {
#         "length": 9,
#         "offset": 0,
#         "type": "user",
#         "id": "100001507477935",
#         "name": "Randy Wei"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T03:07:26+0000",
#       "message": "Randy Wei Thanks for your input",
#       "id": "567847006643510",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Gerald Leung",
#        "id": "1170234525"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T05:19:09+0000",
#       "message": "Yeah, mine's the same.  All it is is a forwarding address.",
#       "id": "567884699973074",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Matt Orzechowski",
#     "id": "100000670167218"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567698423325035",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567698423325035",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T01:57:02+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTM5MDc0NzQyNg==",
#       "before": "MTcxNzE0MjY1Ng=="
#      },
#      "next": "https://graph.facebook.com/266736903421190_567698423325035/likes?access_token=CAACEdEose0cBAGmngXljzIoIg84zDWFeuxGxO1ixulIDUkZBhzqMljCvhJnBwwR2gSKuG1lYGfsfoCicJ4MCNcCjXmIbYZC1pAd2Opvcowum88DImGSBxbUXOPhop2IPKSbjgLvAxc72znespZBgvMCzB4KZBrynvo3noo2HnMc9CLnaXuZAFDGDODoNYz3KSlOZCQZC7SdIQZDZD&limit=25&after=MTM5MDc0NzQyNg%3D%3D"
#     },
#     "data": [
#      {
#       "id": "1717142656",
#       "name": "Willem Van Eck"
#      },
#      {
#       "id": "100000501366367",
#       "name": "Ross Teixeira"
#      },
#      {
#       "id": "740239808",
#       "name": "Japheth Wong"
#      },
#      {
#       "id": "538312121",
#       "name": "Paroma Varma"
#      },
#      {
#       "id": "521488003",
#       "name": "Edwin Xie"
#      },
#      {
#       "id": "1340332255",
#       "name": "Aleksandrina Stoyanova"
#      },
#      {
#       "id": "100000044448800",
#       "name": "Marion Halim"
#      },
#      {
#       "id": "1079833636",
#       "name": "Helen Wang"
#      },
#      {
#       "id": "730212014",
#       "name": "Alex Thomas Ren"
#      },
#      {
#       "id": "661301213",
#       "name": "Alan Yao"
#      },
#      {
#       "id": "100004150812127",
#       "name": "Chenning Kathie Zhang"
#      },
#      {
#       "id": "1721541838",
#       "name": "Daylen Yang"
#      },
#      {
#       "id": "640304895",
#       "name": "Denton Xu"
#      },
#      {
#       "id": "548914619",
#       "name": "Kurush Dubash"
#      },
#      {
#       "id": "1380446553",
#       "name": "Tiffany Chen"
#      },
#      {
#       "id": "100001270403390",
#       "name": "Calvin Li"
#      },
#      {
#       "id": "100003348651826",
#       "name": "Corten Clemente Singer"
#      },
#      {
#       "id": "100001245498803",
#       "name": "Smitha Milli"
#      },
#      {
#       "id": "1468078060",
#       "name": "Joel Whang"
#      },
#      {
#       "id": "1121635119",
#       "name": "Apoorve Agarwal"
#      },
#      {
#       "id": "1593495833",
#       "name": "Risa Pesavento"
#      },
#      {
#       "id": "1820468903",
#       "name": "Melanie Cebula"
#      },
#      {
#       "id": "100000325628038",
#       "name": "Kevin Guo"
#      },
#      {
#       "id": "529431301",
#       "name": "Pradyumn Shroff"
#      },
#      {
#       "id": "1390747426",
#       "name": "Andrew Liu"
#      }
#     ]
#    },
#    "created_time": "2013-12-09T19:42:44+0000",
#    "message": "CS61B was expanded to 1098 people!",
#    "type": "status",
#    "id": "266736903421190_567698423325035",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3ODIzNjc5OTc5MTc2",
#       "before": "NTY3Njk4NzIzMzI1MDA1"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Josh S",
#        "id": "505994663"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:43:44+0000",
#       "message": "Damn that's a lot of people.",
#       "id": "567698723325005",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "John Satoshi Okahata",
#        "id": "806038010"
#       },
#       "like_count": 12,
#       "can_remove": false,
#       "created_time": "2013-12-09T19:55:51+0000",
#       "message": "Ze CS bubble's gonna pop",
#       "id": "567702573324620",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Chenning Kathie Zhang",
#        "id": "100004150812127"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T23:16:36+0000",
#       "message": "but how comes they didnt add lab & discussion sessions?",
#       "id": "567771016651109",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Alex Thomas Ren",
#        "id": "730212014"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-10T00:07:17+0000",
#       "message": "probably still finding TAs",
#       "id": "567787876649423",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Yunjae Joseph Cho",
#        "id": "571060740"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2013-12-10T01:54:59+0000",
#       "message": "and let's hire whoever wants to TA. lol",
#       "id": "567822816645929",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Mehrdad Ni",
#        "id": "100001128747196"
#       },
#       "message_tags": [
#        {
#         "length": 13,
#         "offset": 0,
#         "type": "user",
#         "id": "1573720017",
#         "name": "Thanh H\u1ea3i Mai"
#        }
#       ],
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-10T01:57:02+0000",
#       "message": "Thanh H\u1ea3i Mai LOL same here",
#       "id": "567823679979176",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Seungwoo Choi",
#     "id": "100001253528903"
#    },
#    "caption": "Attachment UnavailableThis attachment may have been removed or the person who shared it may not have permission to share it with you.",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567808943313983",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567808943313983",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T01:12:31+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "ODIwNjkzNA==",
#       "before": "MTQ5MTkxMjk5Nw=="
#      }
#     },
#     "data": [
#      {
#       "id": "1491912997",
#       "name": "Allan Tang"
#      },
#      {
#       "id": "8206934",
#       "name": "Mike Harvey"
#      }
#     ]
#    },
#    "created_time": "2013-12-10T01:12:31+0000",
#    "message": "http://www.lrb.co.uk/v35/n03/rebecca-solnit/diary\n\nI think it's important to think about the social implications of science and technology, especially to those who are or will be involved in it (like us). In the attached article, Rebecca Solnit discusses the tech boom in Silicon Valley and what it means for those who benefit from it and those who don't. Might not be the shortest read, but it's well worth it.",
#    "type": "status",
#    "id": "266736903421190_567808943313983"
#   },
#   {
#    "from": {
#     "name": "Anthony Polloreno",
#     "id": "1796525865"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567206413374236",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567206413374236",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-10T00:15:05+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTE3MDIzNDUyNQ==",
#       "before": "MTY3NjI1OTMzNw=="
#      }
#     },
#     "data": [
#      {
#       "id": "1676259337",
#       "name": "Kabir Chandrasekher"
#      },
#      {
#       "id": "100004461934570",
#       "name": "\u5c3b \u30b7\u30e9\u3055\u3093"
#      },
#      {
#       "id": "604743693",
#       "name": "Rohin Shah"
#      },
#      {
#       "id": "1170234525",
#       "name": "Gerald Leung"
#      }
#     ]
#    },
#    "created_time": "2013-12-08T21:13:14+0000",
#    "message": "CS 191C PEOPLE:\nJoint CS Theory-Condensed Matter Seminar\n\nTitle: Taming a quantum tiger\nSpeaker: Umesh Vazirani, U.C. Berkeley\n2:30 pm Monday Dec 9, Banatao Auditorium, Sutardja Dai Hall\n\nAbstract: \n\nQuantum computation has taught us that a quantum system is better\nvisualized as a wild tiger rather than a tame Schrodinger's cat.\nIndeed the exponential power of quantum systems, which makes quantum\ncomputers possible, is also an enormous obstacle to analyzing and\nunderstanding physical systems. Are there situations in which we \ncan neutralize this curse of exponentially? In this talk I will address \nthis question in two settings:\n\n1. Are there general classes of quantum systems whose states can \nbe efficiently (polynomially) computed on a traditional classical\ncomputer? And can we explain the remarkable practical success \nof the heuristic DMRG for 1D systems?\n\n2. Is it possible for a classical experimentalist to test that an\nuntrusted quantum system behaves as commanded? For example, is it\npossible to test that a claimed quantum computer is really quantum?\n\nThe talk will discuss recent breakthroughs in both settings, as well\nas many exciting open questions. It will also briefly touch upon recent\nresults that shed some light on the D-Wave controversy. The talk may\nalso be thought of as an \"amuse bouche\" for the upcoming semester-long \nprogram on Quantum Hamiltonian Complexity at the Simons Institute, and \nI will make every attempt to keep the discussion widely accessible.\n\nBased on joint work with Itai Arad, Alexei Kitaev, Zeph Landau and Thomas Vidick, \nBen Reichardt and Falk Unger, and Seung Woo Shin.",
#    "type": "status",
#    "id": "266736903421190_567206413374236",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3Nzg5OTM2NjQ5MjE3",
#       "before": "NTY3NDI1NzU2Njg1NjM1"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Zander Giuffrida",
#        "id": "1306573482"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-09T06:33:38+0000",
#       "message": "noooooooooo this is during my review session, is this going to be recorded?",
#       "id": "567425756685635",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Gerald Leung",
#        "id": "1170234525"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T00:14:03+0000",
#       "message": "I hope I recorded most of it.  I'll see about figuring out how to get it off my phone and up online somewhere (I lost power for a few minutes, about 10 minutes in, so I need to figure out how to splice together 2 videos as well first).",
#       "id": "567789656649245",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Gerald Leung",
#        "id": "1170234525"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-10T00:15:05+0000",
#       "message": "Also, currently I've NO idea how good the sound/picture/stability quality is yet until I can see it on a full screen, haha.",
#       "id": "567789936649217",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Harish Kumar",
#     "id": "1134859569"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567678946660316",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567678946660316",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-09T20:26:39+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3NzEyNTE5OTkwMjky",
#       "before": "NTY3NzEyNTE5OTkwMjky"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Ronald Kwan",
#        "id": "585335189"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-09T20:26:39+0000",
#       "message": "not sure about the actual content, but 154 has a (reportedly) bad prof while 189 has a decent prof.",
#       "id": "567712519990292",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-09T18:45:31+0000",
#    "message": "What's your opinion on the machine learning class offered in the Stats department, STAT 154? I've already taken CS188 but now I'm deciding whether to take CS189 or Stat 154 or both. I just want to know the overlap between the 2 classes, if there is any.",
#    "type": "status",
#    "id": "266736903421190_567678946660316"
#   },
#   {
#    "from": {
#     "name": "Ronak Vora",
#     "id": "518566844"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567416100019934",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567416100019934",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-09T06:28:38+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3NDI0NTUwMDE5MDg5",
#       "before": "NTY3NDI0NTUwMDE5MDg5"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Raemond Bergstrom-Wood",
#        "id": "100002812394515"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-09T06:28:38+0000",
#       "message": "I assume when they get more TA/GSIs for the class. This semester the class was heavily affected by the GSI shortage and they don't want it to happen again.",
#       "id": "567424550019089",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-09T06:08:05+0000",
#    "message": "anyone know when they are going to start filling the 200 open seats for 161 ?",
#    "type": "status",
#    "id": "266736903421190_567416100019934"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQALS2YIM9l4s9-y&w=154&h=154&url=http%3A%2F%2Flh3.googleusercontent.com%2Fuy3HQlPPel_qsIn6G8Za5SgyJBD6JIRx-uIEEFgF0XGbyHYeJQBPSSDpC4-wj-Ttdvg",
#    "from": {
#     "name": "Arjun Ghai",
#     "id": "543681184"
#    },
#    "name": "CETSA Membership Form",
#    "caption": "docs.google.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567231850038359",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/567231850038359",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-08T22:48:10+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "link": "https://docs.google.com/forms/d/1fb5lr77I0lLrtZuMmfuO_GWCMyQ-HxmZ7DMCf0FjLjo/viewform",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NjI4NjQwMTMz",
#       "before": "MTAwMDAwMjY2NjUyNTE5"
#      }
#     },
#     "data": [
#      {
#       "id": "100000266652519",
#       "name": "Sebastian Edward Shanus"
#      },
#      {
#       "id": "628640133",
#       "name": "Pavan Patel"
#      }
#     ]
#    },
#    "created_time": "2013-12-08T22:48:10+0000",
#    "message": "Looking to put the hours you have spent understanding new material to good use and maybe make some money out of it. The Center for Entrepreneurship and Technology Student Association (CETSA) connects students to large corporations based here in the Bay Area. Fill out the membership form and see how CETSA can help grow your network and land you a job/internship. https://docs.google.com/forms/d/1fb5lr77I0lLrtZuMmfuO_GWCMyQ-HxmZ7DMCf0FjLjo/viewform",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "266736903421190_567231850038359",
#    "description": "By signing up for CETSA, you will gain exclusive access to our internal network and tech entities such as Pandora, Yelp, Andreessen Horowitz, Spoon Rocket, and SkyDeck."
#   },
#   {
#    "from": {
#     "name": "Jordan Niell",
#     "id": "1613986461"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566044683490409",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566044683490409",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-08T18:56:59+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTE4NzU2NjQ1Ng==",
#       "before": "MTM2MTEyNjEwNQ=="
#      }
#     },
#     "data": [
#      {
#       "id": "1361126105",
#       "name": "Maryam Labib"
#      },
#      {
#       "id": "1513917498",
#       "name": "Calley Wang"
#      },
#      {
#       "id": "1086986855",
#       "name": "Krishna Parashar"
#      },
#      {
#       "id": "1187566456",
#       "name": "Pratyush Mishra"
#      }
#     ]
#    },
#    "created_time": "2013-12-06T17:16:29+0000",
#    "message": "Are there currently any activists groups on campus dedicated solely/primarily to opposing government spying/PRISM/NSA programs?",
#    "type": "status",
#    "id": "266736903421190_566044683490409",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY3MTUyMTQ2NzEyOTk2",
#       "before": "NTY2MTgwMjQwMTQzNTIw"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Jordan Niell",
#        "id": "1613986461"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-06T23:28:36+0000",
#       "message": "Guess this might be a no, then?",
#       "id": "566180240143520",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Alex Thomas Ren",
#        "id": "730212014"
#       },
#       "like_count": 10,
#       "can_remove": false,
#       "created_time": "2013-12-07T00:43:06+0000",
#       "message": "Perhaps they are preparing to contact you offline. You never know when big bro could be watching, after all :)",
#       "id": "566208690140675",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Krishna Parashar",
#        "id": "1086986855"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-08T18:56:43+0000",
#       "message": "WE ARE ANONYMOUS. WE ARE LEGION. WE STAND FOR ALL. WE STAND FOR NONE. WE ARE EVERYBODY. WE ARE NOBODY. WE DO NOT FORGIVE. WE DO NOT FORGET. EXPECT US.",
#       "id": "567152043379673",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Krishna Parashar",
#        "id": "1086986855"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-08T18:56:59+0000",
#       "message": "Oh shit did I just post that publicly?! :O",
#       "id": "567152146712996",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Colin Garcia",
#     "id": "677076825"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566757880085756",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566757880085756",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-08T18:55:11+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
# ...
#      }
#     },
#     "data": [
#      {
#       "id": "656976797",
#       "name": "Andrew Huang"
#      }
#     ]
#    },
#    "created_time": "2013-12-07T02:59:52+0000",
#    "message": "Regarding CS grad school apps:\nI've heard it's a good idea to mention the name of faculty name in essays...\nbut most applications already ask you to list faculty you're interested in.\n\nShould you still try to mention them in your essay, or is the application sufficient?",
#    "type": "status",
#    "id": "266736903421190_566250736803137",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY2MzA0NjEwMTMxMDgz",
#       "before": "NTY2MjUxNzYwMTM2MzY4"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Lisa 'Paco' Yan",
#        "id": "1333170185"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-07T03:03:25+0000",
#       "message": "why not",
#       "id": "566251760136368",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Mehrdad Ni",
#        "id": "100001128747196"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-07T03:07:23+0000",
#       "message": "Well it'd make the essay longer, plus I'd have to fit it in the flow somehow. I'm wondering if it's actually beneficial instead of just being repetitive, since it's already mentioned elsewhere?",
#       "id": "566252786802932",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Eric Kim",
#        "id": "1087890421"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-07T03:13:59+0000",
#       "message": "I've heard that most people add in a final paragraph talking about why school X is particularly relevant to their graduate studies. Usually you'd want to list particular faculty whose research interests align well with those of your own. \n\nI'm not sure if it's particularly critical or not. For MS programs, it probably isn't. For PhD, it can only strengthen your application (as it shows that you've done your homework on their program).",
#       "id": "566254976802713",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Akihiro Matsukawa",
#        "id": "500642294"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-07T03:47:44+0000",
#       "message": "Yes, you should be more specific than \"I want to work with X\" with why",
#       "id": "566267540134790",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Vincent Lee",
#        "id": "1274313314"
#       },
#       "like_count": 5,
#       "can_remove": false,
#       "created_time": "2013-12-07T05:43:16+0000",
#       "message": "^^ Yes. You should do that at most it will help you get past the machine learning algorithms departments are starting to use on applications. At worst, it makes you look like you did your homework. Also for other things that are important, see UT Austin's GRADE system. It's scary as shit: http://www.cs.utexas.edu/~austin/papers/waters.iaai13.pdf",
#       "id": "566299660131578",
#       "user_likes": true
#      },
#      {
#       "from": {
#        "name": "Mehrdad Ni",
#        "id": "100001128747196"
#       },
#       "message_tags": [
#        {
#         "length": 7,
#         "offset": 51,
#         "type": "user",
#         "id": "1274313314",
#         "name": "Vincent"
#        }
#       ],
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-07T05:45:35+0000",
#       "message": "o__o #goddammit\nThanks so much for mentioning that Vincent O:",
#       "id": "566300456798165",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Vincent Lee",
#        "id": "1274313314"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-07T05:47:51+0000",
#       "message": "No problem. #goddamnit",
#       "id": "566301013464776",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Ronald Kwan",
#        "id": "585335189"
#       },
#       "message_tags": [
#        {
#         "length": 7,
#         "offset": 0,
#         "type": "user",
#         "id": "1274313314",
#         "name": "Vincent"
#        }
#       ],
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-07T05:48:27+0000",
#       "message": "Vincent: that's simultaneously really cool (from a technical perspective), and really scary (from an applicant's perspective) :O",
#       "id": "566301156798095",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Vincent Lee",
#        "id": "1274313314"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-07T05:50:53+0000",
#       "message": "I know right =_= The good news is you guys are applying from the \"elite\" institution category so you're app will probably be considered more carefully even with this machine learning filter.",
#       "id": "566301633464714",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Eric Kim",
#        "id": "1087890421"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-07T06:04:49+0000",
#       "message": "I don't even know what to think about that paper, haha. Horror? Hilarity? But the \"Learned Feature Weights\" section is pretty interesting, you get to see which features the classifier ends up selecting as being most-discriminative.\n\nInteresting that the classifier was unable to get any useful information from the Statement of Purpose, unlike w/ the Letters of Recommendation. Does that just mean that SoP's tend to exhibit a larger variety of language/diction? That trying to judge the *semantic* meaning of SoP's via a naive BoW model is a futile exercise? Or is it that admissions councils really don't read the SoP's until after the initial (or first-few-rounds) of application pruning? Haha. Iinteresting....",
#       "id": "566304610131083",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "name": "Pedro Rodriguez",
#     "id": "1320273616"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566297653465112",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566297653465112",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-07T05:34:50+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "created_time": "2013-12-07T05:34:50+0000",
#    "message": "Hi all, I am going to be attending Berkeley an extra semester next fall, but it seems a lot of leases are 1 year leases, instead of only 1 semester or so. Suggestions on places near Soda Hall that are not super expensive and preferably 1 bed/studio/2bed?",
#    "type": "status",
#    "id": "266736903421190_566297653465112"
#   },
#   {
#    "from": {
#     "name": "Alex Arkady",
#     "id": "100006219300267"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566229720138572",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/566229720138572",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-07T01:47:54+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "created_time": "2013-12-07T01:47:54+0000",
#    "message": "Hi, is anyone selling the CS170 textbook? I lost mine and need one. (I know it is online but I want a physical book. ;)  )",
#    "type": "status",
#    "id": "266736903421190_566229720138572"
#   },
#   {
#    "from": {
#     "name": "Vy Ly",
#     "id": "100000137185584"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565742233520654",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565742233520654",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-06T08:35:19+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY1NzkwMTQzNTE1ODYz",
#       "before": "NTY1NzQyNDQzNTIwNjMz"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Don-Wook Shin",
#        "id": "100002591239941"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-06T05:25:33+0000",
#       "message": "Both.",
#       "id": "565742443520633",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jordon Wing",
#        "id": "1399776013"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-06T05:26:04+0000",
#       "message": "It's 12-2. http://www.eecs.berkeley.edu/Scheduling/CS/schedule-next.html",
#       "id": "565742560187288",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Austin Le",
#        "id": "100002196049015"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-06T05:27:32+0000",
#       "message": "Yes, both. 1-2 on Monday and 12-2 on Wednesday for a total of 3 hours of lecture per week.",
#       "id": "565742856853925",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Mangesh Gandhi",
#        "id": "672202177"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-06T05:40:00+0000",
#       "message": "Are the lectures webcasted? I have a time conflict with another class I need to take",
#       "id": "565746416853569",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Austin Le",
#        "id": "100002196049015"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-12-06T06:26:39+0000",
#       "message": "I don't think they've been webcasted in a while (there are some from years ago online), but the lecture notes are posted on the website. I've heard from past students that the lecture notes do a pretty good job of covering the material that Shewchuk lectures on in class.",
#       "id": "565758106852400",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Emily Reinhold",
#        "id": "1055423436"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-12-06T06:34:46+0000",
#       "message": "They were webcasted Spring 2013 with Shewchuk: http://webcast.berkeley.edu/playlist#c,s,Spring_2013,-XXv-cvA_iCZphAM_CG499wyMaJh_6dW",
#       "id": "565760080185536",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Manny Jois",
#        "id": "775074164"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-06T08:35:19+0000",
#       "message": "Shewchuk's lecture notes are fabulous.",
#       "id": "565790143515863",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-06T05:25:04+0000",
#    "message": "For CS61B (spring 2014), is lecture on Wednesday 1-2pm or 12-1pm? Schedulebuilder and tele-bears have different times.",
#    "type": "status",
#    "id": "266736903421190_565742233520654"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQDO5HCkaX_3RRSm&w=130&h=130&url=http%3A%2F%2Fi1.ytimg.com%2Fvi%2FAiVKfNeRbPQ%2Fmaxresdefault.jpg",
#    "from": {
#     "name": "John Li",
#     "id": "1524706343"
#    },
#    "name": "What is Visual.ly?",
#    "source": "http://www.youtube.com/v/AiVKfNeRbPQ?autohide=1&version=3&autoplay=1",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565630120198532",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565630120198532",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-06T00:56:44+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "link": "https://www.youtube.com/watch?v=AiVKfNeRbPQ",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY1NjY1NjE2ODYxNjQ5",
#       "before": "NTY1NjU5NjA2ODYyMjUw"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "John Li",
#        "id": "1524706343"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-06T00:52:01+0000",
#       "message": "Looking for videographers as well",
#       "id": "565659606862250",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Eric Quach",
#        "id": "520842843"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-06T00:56:44+0000",
#       "message": "What's your budget?",
#       "id": "565665616861649",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-05T23:17:56+0000",
#    "message": "Hi Everyone!\n\nI'm creating an app to drive large amounts of donations to Typhoon Haiyan relief organizations in the Philippines. I want to make a viral video with infographics/good designs to spread the word quickly on social media so we can get as much donated as quickly as possible. The video will be something like the (irrelevant) one in the link below, but not nearly as complicated/difficult to make. MUCH simpler. \n\nIf you or anyone you know has the necessary design and video shooting/editing skills to help make such a video, I'd really appreciate an intro =) You by no means need to be a pro, and I'm willing to pay as well. Thanks and good luck with finals!",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yj/r/v2OnaTyTQZE.gif",
#    "type": "video",
#    "id": "266736903421190_565630120198532",
#    "description": "Want to create a video like this? https://marketplace.visual.ly/ Introducing Visually, a place to Create, Share and Explore Great Visualizations."
#   },
#   {
#    "from": {
#     "name": "David Huang",
#     "id": "692240653"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565316850229859",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/266736903421190/posts/565316850229859",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-12-05T18:08:27+0000",
#    "to": {
#     "data": [
#      {
#       "name": "Computer Science",
#       "id": "266736903421190"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NTY1NTI2MjY2ODc1NTg0",
#       "before": "NTY1MzE3NDkwMjI5Nzk1"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "S Zayd Enam",
#        "id": "100004737999032"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2013-12-05T08:39:39+0000",
#       "message": "no offense to you but fuck ets",
#       "id": "565317490229795",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "David Huang",
#        "id": "692240653"
#       },
#       "message_tags": [
#        {
#         "length": 4,
#         "offset": 10,
#         "type": "user",
#         "id": "100004737999032",
#         "name": "Zayd"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-12-05T18:08:27+0000",
#       "message": "Aye sir.  Zayd are you planning on offering our fellow graduate-school-minded students an alternative to this monopolistic monster?",
#       "id": "565526266875584",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-12-05T08:36:56+0000",
#    "message": "Have a couple of brand-new, 2013-2014 editions of GRE books for sale.  Message me if interested.",
#    "type": "status",
#    "id": "266736903421190_565316850229859"
#   }
#  ]
# }

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9751ded1a4a4> in <module>()
#      12 # dictionary comprehensions
#      13
# ---> 14 friends = g.get_connections("me", "friends")['data']
#      15
#      16 likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data']
#
# NameError: name 'g' is not defined

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9aa1d5d74643> in <module>()
#       5 from collections import Counter
#       6 friends_likes = Counter([like['name']
# ----> 7                          for friend in likes
#       8                            for like in likes[friend]
#       9                                if like.get('name')])
#
# NameError: name 'likes' is not defined

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt
# Out:
# Top 10 like categories for friends
# +-------------------------+------+
# | Category                | Freq |
# +-------------------------+------+
# | Community               |  366 |
# | Musician/band           |  227 |
# | Non-profit organization |   83 |
# | Movie                   |   80 |
# | Tv show                 |   70 |
# | Education               |   70 |
# | Public figure           |   69 |
# | Product/service         |   60 |
# | Media/news/publishing   |   53 |
# | Website                 |   53 |
# +-------------------------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt
# Out:
# Number of likes per friend
# +--------------------------+-----------+
# | Friend                   | Num Likes |
# +--------------------------+-----------+
# | Alex Chao                |        25 |
# | Hil Alsibai              |        25 |
# | Chidofukuto Rimokatoji   |        25 |
# | Kyle Yu                  |        25 |
# | Thien Anh Vo             |        25 |
# | Reena Shah               |        25 |
# | Nguyen Do                |        25 |
# | Tuan Anh Nguyen Dang     |        25 |
# | David Barrera            |        25 |
# | Mũm Mĩm                  |        25 |
# | Roland Shen              |        25 |
# | Ben Lewis                |        25 |
# | Hao Le                   |        25 |
# | Trung Bim                |        25 |
# | Cheryl Kwan              |        25 |
# | Nguyen Dat               |        25 |
# | Tuan Ho                  |        25 |
# | Mana Nabati              |        25 |
# | Việt Huy                 |        25 |
# | Radhesh Devendran        |        25 |
# | Hien Le                  |        25 |
# | Stephen Huang            |        25 |
# | Su Htet Htet Win         |        25 |
# | Henti Ogilecun           |        25 |
# | Dao Duy Anh Duc          |        25 |
# | Annie Pham               |        25 |
# | Dang Dinh Hung           |        25 |
# | Vinay Gupta              |        25 |
# | Alex Matevish            |        25 |
# | Vy Do                    |        25 |
# | Van Dang                 |        25 |
# | Elese Lorentzen-Gadd     |        25 |
# | Ferheen Abbasi           |        25 |
# | Alisha King              |        25 |
# | Trang Tran               |        25 |
# | Tú Uyên                  |        25 |
# | Khoi Tran                |        25 |
# | Mina Pham                |        25 |
# | Amy PDang                |        25 |
# | Tuan Doan                |        25 |
# | Shannon Camacho          |        25 |
# | Hạnh Đinh                |        25 |
# | Zee Pham                 |        25 |
# | Quân Nguyễn              |        25 |
# | Ngân Nguyễn              |        25 |
# | David Smith              |        25 |
# | Chibi Pup                |        25 |
# | Luffy H. Từ              |        25 |
# | Теймур Музшфек           |        25 |
# | Wanh Lay                 |        25 |
# | Duyen Truong             |        25 |
# | Morgan Fabian            |        25 |
# | Phuoc 'Kiddo' Nguyen     |        25 |
# | Minh Slim                |        25 |
# | Bryanna Reed             |        25 |
# | Dang N. Le               |        25 |
# | Hằng Phạm                |        25 |
# | Kamran Siddiqui          |        25 |
# | Henry Geerlings          |        25 |
# | Ha Le                    |        25 |
# | Kevin Huynh              |        25 |
# | Linh Nguyen              |        25 |
# | Tj Dhadwal               |        25 |
# | Khoa Tran                |        25 |
# | Toan Nguyen              |        25 |
# | Fatty An Tran            |        25 |
# | Neo Hung ≧◡≦             |        25 |
# | Phương Thảo Nguyễn       |        25 |
# | Nhan Thanh Nguyen        |        25 |
# | Ntd Thuy                 |        25 |
# | Trevor Davenport         |        25 |
# | Weier Wan                |        25 |
# | David Bui                |        25 |
# | Michael Romain           |        25 |
# | Quân Quay Quần           |        25 |
# | Khang Nguyen Chi         |        25 |
# | Simon Shaolei Du         |        25 |
# | Desiree Chow             |        25 |
# | Tue Cao Mai              |        25 |
# | Jack Lin                 |        25 |
# | Claire Thompson          |        25 |
# | Minh Tri Le              |        25 |
# | Jake Long Nguyen         |        25 |
# | Joey Amerison            |        24 |
# | Stanley Yang             |        24 |
# | Dan Le                   |        24 |
# | Ethan Bauer              |        24 |
# | Phan Giap Hoang Huy      |        22 |
# | Đào Minh Quang           |        21 |
# | Liz Huynh                |        20 |
# | Takeo Hiraki             |        17 |
# | Ietee Pandey             |        15 |
# | Carl Shan                |        13 |
# | Andrew Koth              |        13 |
# | David Casas-Mao          |         9 |
# | Kishan Karu              |         9 |
# | Đào Ngọc Đăng Khoa       |         9 |
# | Steven Belding           |         5 |
# | Phạm Minh Trí            |         5 |
# | Tram Do                  |         3 |
# | Vân Anh                  |         2 |
# | Michael Zhang            |         0 |
# | Teresa Rose Tenfelder    |         0 |
# | Giovanni Morgan          |         0 |
# | Ann Johnson              |         0 |
# | Phuc Nguyen              |         0 |
# | Christina Ho             |         0 |
# | Alice Man                |         0 |
# | Michael Suey             |         0 |
# | Jennifer Fei             |         0 |
# | Darrell Vermilion        |         0 |
# | Minh Trang Trương Nguyễn |         0 |
# | Kien Vinh Tu             |         0 |
# | Ami Bigit                |         0 |
# | Jody Zhang               |         0 |
# +--------------------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt
# Out:
# My likes
# +-------------------------------------------------------+
# | Name                                                  |
# +-------------------------------------------------------+
# | KeepSafe                                              |
# | Open Academy                                          |
# | I fucking love science                                |
# | resu.me                                               |
# | UC Berkeley Robotics                                  |
# | UC Berkeley AMPLab                                    |
# | Berkeleytime                                          |
# | Robert Reich                                          |
# | Berkeley Cyber Security Team                          |
# | UC Berkeley HKN                                       |
# | UC Berkeley Fung Institute For Engineering Leadership |
# | UC Berkeley Jobs                                      |
# | Startup Weekend Berkeley                              |
# | SpoonRocket                                           |
# | Data Science at Berkeley                              |
# | Pokémon                                               |
# | BerkeleyX                                             |
# | Engineering Software as a Service                     |
# | Vanessa pelaez                                        |
# | Những câu nói bất hủ của Vozer                        |
# | Facebook Engineering                                  |
# | SUPERB Productions                                    |
# | Emily Ratajkowski                                     |
# | Hilarious Texts                                       |
# | TĐN Confessions                                       |
# +-------------------------------------------------------+
#
# My common likes with friends
# +--------------------------------+
# | Name                           |
# +--------------------------------+
# | TĐN Confessions                |
# | Những câu nói bất hủ của Vozer |
# | KeepSafe                       |
# | UC Berkeley Jobs               |
# | SpoonRocket                    |
# | I fucking love science         |
# | UC Berkeley Robotics           |
# | Startup Weekend Berkeley       |
# | Berkeleytime                   |
# | Robert Reich                   |
# | Data Science at Berkeley       |
# +--------------------------------+

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=np.arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# My similar friends (ranked)
# +------------------+--------------+
# | Friend           | Common Likes |
# +------------------+--------------+
# | Alex Chao        |            2 |
# | Nguyen Do        |            1 |
# | Shannon Camacho  |            1 |
# | Ha Le            |            1 |
# | Hil Alsibai      |            1 |
# | Hạnh Đinh        |            1 |
# | Morgan Fabian    |            1 |
# | Nguyen Dat       |            1 |
# | Minh Tri Le      |            1 |
# | Thien Anh Vo     |            1 |
# | Weier Wan        |            1 |
# | Simon Shaolei Du |            1 |
# | Reena Shah       |            1 |
# | Roland Shen      |            1 |
# | Annie Pham       |            1 |
# | Ben Lewis        |            1 |
# | Trang Tran       |            1 |
# | Tj Dhadwal       |            1 |
# | Đào Minh Quang   |            1 |
# +------------------+--------------+

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
nx.draw(nxg)

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)
# Out:
# Num cliques: 727
# Avg clique size: 13
# Max clique size: 20
# Num max cliques: 38
#
# Friends in all max cliques:
# [
#  "me",
#  "Nguyen Do",
#  "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#  "Trung Bim",
#  "Ntd Thuy",
#  "T\u00fa Uy\u00ean",
#  "Ha Le",
#  "Khang Nguyen Chi",
#  "Vy Do",
#  "Chibi Pup",
#  "Tuan Anh Nguyen Dang",
#  "Jake Long Nguyen",
#  "Fatty An Tran",
#  "Mina Pham",
#  "Annie Pham",
#  "Ng\u00e2n Nguy\u1ec5n"
# ]
#
# Max cliques:
# [
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "M\u0169m M\u0129m"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Henti Ogilecun"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "M\u0169m M\u0129m"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "M\u0169m M\u0129m"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "M\u0169m M\u0129m"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "Thien Anh Vo",
#   "Jake Long Nguyen",
#   "Chibi Pup",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Henti Ogilecun"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Wanh Lay",
#   "Van Dang",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Phan Giap Hoang Huy",
#   "Mina Pham",
#   "Trang Tran"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Amy PDang"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "H\u1ea1nh \u0110inh"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Minh Slim"
#  ],
#  [
#   "me",
#   "Fatty An Tran",
#   "Trung Bim",
#   "Vy Do",
#   "Minh Trang Tr\u01b0\u01a1ng Nguy\u1ec5n",
#   "Tuan Anh Nguyen Dang",
#   "T\u00fa Uy\u00ean",
#   "Nguyen Do",
#   "Ntd Thuy",
#   "Ha Le",
#   "Annie Pham",
#   "Ng\u00e2n Nguy\u1ec5n",
#   "\u0110\u00e0o Minh Quang",
#   "Chibi Pup",
#   "Jake Long Nguyen",
#   "Khang Nguyen Chi",
#   "Tuan Doan",
#   "Van Dang",
#   "Mina Pham",
#   "Trang Tran"
#  ]
# ]

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/ch02-facebook/viz/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
